# %%
# 載入基礎套件
import numpy as np
np.random.seed(1)

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.random.randint(0, 50, 1000)
y = -(x + np.random.randint(0, 50, 1000)) + 100
np.cov(x, y)
# Out:
# array([[ 210.19274875, -206.36174374],
#        [-206.36174374,  414.16124024]])

# %%
plt.scatter(x, y)
